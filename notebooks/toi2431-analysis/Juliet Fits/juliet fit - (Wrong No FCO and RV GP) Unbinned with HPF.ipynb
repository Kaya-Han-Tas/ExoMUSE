# %%
import ironman
import numpy as np
import pandas as pd
import corner
import matplotlib.pyplot as plt
import rmfit
from astropy import units as u
from astropy import constants as c
import juliet
from astropy.timeseries import LombScargle

# %%
#from matplotlib import rc
#rc('font', **{'family':'sans-serif'}) Use only if you have pdflatex (recommended)
#rc('text', usetex=True)

plt.rcParams['xtick.top'] =  True
plt.rcParams['xtick.direction'] =  'in'
plt.rcParams['xtick.major.width'] =  1.0
plt.rcParams['xtick.minor.width'] =  1.0
plt.rcParams['ytick.right'] =  True
plt.rcParams['ytick.direction'] =  'in'
plt.rcParams['ytick.major.width'] = 1.0
plt.rcParams['ytick.minor.width'] =  1.0
plt.rcParams['lines.markeredgewidth'] =  1.0

# %%
dataset = juliet.load(input_folder = 'TOI-2431_juliet_RVGP_run', out_folder = 'TOI-2431_juliet_RVGP_run')
results = dataset.fit(sampler = "dynamic_dynesty")
# Out:
# Detected dynamic_dynesty sampler output files --- extracting from TOI-2431_juliet_RVGP_run/_dynesty_DNS_posteriors.pkl

# %%
#results.nested_sampling.results.logz[-1]

# %%
P = juliet.utils.get_quantiles(results.posteriors['posterior_samples']['P_p1'])[0]
t0 = juliet.utils.get_quantiles(results.posteriors['posterior_samples']['t0_p1'])[0]
print(P,t0)
# Out:
# 0.22419578269075413 2460258.8685626294

# %% [markdown]
# # Photometry

# %%
def plot_with_gp(instrument, title, name, P, t0):
    global results
    x = dataset.times_lc[instrument]
    phases = juliet.utils.get_phases(dataset.times_lc[instrument], P, t0)
    transit_plus_GP = results.lc.evaluate(instrument)
    transit_model = results.lc.model[instrument]['deterministic']
    gp_model = results.lc.model[instrument]['GP']

    jitter = np.median(results.posteriors['posterior_samples']['sigma_w_'+instrument]) / 1e6
    
    mask = np.logical_or(np.logical_and(phases>-0.05,phases<-0.02),np.logical_and(phases<0.05,phases>0.02))
    #print(mask)
    oot = (dataset.data_lc[instrument] - gp_model)[mask]
    m_inst = 1-np.mean(oot)
    
    # print(x)
    # print(phases)
    # print(transit_plus_GP)
    # print(transit_model)
    # print(gp_model)
    # print(jitter)
    
    #m_inst = juliet.utils.get_quantiles(results.posteriors['posterior_samples']['mflux_'+instrument])[0]
    transit_model = results.lc.model[instrument]['deterministic']
    
    fig, ax = plt.subplots(dpi=100)
    plt.errorbar(phases,dataset.data_lc[instrument]-gp_model+m_inst,yerr = np.sqrt(dataset.errors_lc[instrument]**2.0 + jitter**2.0), fmt = '.', alpha = 0.7)

    idx = np.argsort(phases)
    plt.plot(phases[idx],transit_model[idx], color='black',zorder=10)

    plt.xlim([-0.5,0.5])
    #plt.ylim([0.98,1.02])
    plt.title(title)
    #plt.xlim()
    #plt.ylim([0.995,1.005])
    plt.xlabel('Phase')
    plt.ylabel('Relative flux')
    plt.show()

    return phases, dataset.data_lc[instrument], np.sqrt(dataset.errors_lc[instrument]**2.0 + jitter**2.0), transit_model, m_inst, gp_model

# %%
phase_tess, flux_tess, flux_err_tess, model_tess, m_tess, gp_model_tess = plot_with_gp("TESS","TESS","TESS_det.csv",P,t0)

# %%
def bin_lc(phase, f, num_bins=40):
    # Shift phase from [-0.5, 0.5] to [0, 1] for binning
    phase = np.mod(phase + 1, 1)

    # Define bin edges and centers
    bin_edges = np.linspace(0, 1, num_bins + 1)
    binned_phase = (bin_edges[:-1] + bin_edges[1:]) / 2
    binned_flux = np.full(num_bins, np.nan)  # Initialize with NaNs

    for i in range(num_bins):
        mask = (phase >= bin_edges[i]) & (phase < bin_edges[i + 1])
        if np.any(mask):
            binned_flux[i] = np.mean(f[mask])  # Mean flux in bin

    # Convert phase back to [-0.5, 0.5] for correct plotting
    binned_phase = binned_phase - (binned_phase > 0.5)

    return binned_phase, binned_flux

fig = plt.figure(figsize=(10,6),dpi=150,constrained_layout=True)

gs = fig.add_gridspec(3, 6)
ax1 = fig.add_subplot(gs[:2, :])
ax2 = fig.add_subplot(gs[2, :], sharex = ax1)

phase_bin, flux_bin = bin_lc(phase_tess, flux_tess)

ax1.errorbar(phase_tess*P*24.,flux_tess-gp_model_tess,flux_err_tess,fmt = '.', alpha=0.1,color="cornflowerblue")
idx = np.argsort(phase_tess)
ax1.plot(phase_tess[idx]*P*24.,model_tess[idx], color='crimson',zorder=10,lw=2)

ax1.plot((phase_bin)*P*24.,flux_bin,"o",color="k",zorder=5)

#ax1.set_ylim()
plt.setp(ax1.get_xticklabels(), visible=False)
ax1.set_ylabel('Relative flux',fontsize=14)

res = flux_tess-gp_model_tess-model_tess

phase_res_bin, res_bin = bin_lc(phase_tess, res)

ax2.errorbar(phase_tess*P*24.,res,flux_err_tess,fmt = '.', alpha=0.1,color="cornflowerblue")
ax2.axhline(0.0,lw=2,color="crimson",zorder=30)
ax2.plot((phase_bin)*P*24.,res_bin,"o",color="k",zorder=5)

ax2.set_xlim(-2.5,2.5)
ax2.set_ylim(-0.008,0.008)
#ax2.set_xticks([-2,-1,0,1,2,3])
ax2.set_xlabel(r'Hours from mid-transit',fontsize=14)
ax2.set_ylabel('O - C', fontsize = 14)

ax1.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)

fig.set_facecolor('w')
#plt.tight_layout()
#fig.legend(loc='upper center', bbox_to_anchor=(0.55, 1.07),ncol=6, fancybox=True, fontsize=9)
plt.savefig("TOI-2431_PHOT.png", bbox_inches="tight", dpi=600)
plt.show()
plt.close()

# %% [markdown]
# # Radial Velocities

# %%
def plot_rv(inst):
    global results
    global dataset

    #Define time range for model evaluation
    min_time, max_time = np.min(dataset.times_rv[inst]) - 10, np.max(dataset.times_rv[inst]) + 10
    model_times = np.linspace(min_time+10, max_time+10, 5000)

    ###################################################### For Model Plotting ######################################################
    full_model_inst,components_inst = results.rv.evaluate(inst, t = model_times, GPregressors = model_times, return_components = True)

    fig, ax = plt.subplots(dpi=150)
    
    jitter = 0

    plt.plot(model_times-2454705,full_model_inst - components_inst['mu'],label='Full model',alpha = 0.2,color='black')
    plt.plot(model_times-2454705,results.rv.model[inst]['deterministic'],label = 'Keplerian component', color = 'crimson')
    plt.plot(model_times-2454705,results.rv.model[inst]['GP'], label = 'GP component', alpha = 0.4, color='blue')

    ####################################################### For Data Plotting #######################################################
    full_model,components = results.rv.evaluate(inst, t = dataset.times_rv[inst], GPregressors = dataset.times_rv[inst], return_components = True)
    plt.errorbar(dataset.times_rv[inst]-2454705, dataset.data_rv[inst] - components['mu'] - results.rv.model[inst]["GP"], \
             yerr = dataset.errors_rv[inst], fmt = 'o', label = inst+' data',mec='cornflowerblue', ecolor='cornflowerblue', mfc='white', \
             elinewidth=1)
    
    plt.xlabel("Time (BJD - 2457000)", fontsize=11)
    plt.ylabel("RV (m/s)", fontsize=11)
    plt.legend()
    plt.show()

    return dataset.times_rv[inst], dataset.data_rv[inst], np.sqrt(dataset.errors_rv[inst]**2+jitter**2), components_inst['mu'], results.rv.model[inst]['deterministic'], results.rv.model[inst]['GP'], full_model_inst

# %%
times_neid, rv_neid, rv_err_neid, gamma_neid, model_neid, GP_neid, full_model_neid =  plot_rv("NEID")
times_hpf, rv_hpf, rv_err_hpf, gamma_hpf, model_hpf, GP_hpf, full_model_hpf = plot_rv("HPF")

# %%
fig = plt.figure(figsize=(10,6),dpi=150,constrained_layout=True)

gs = fig.add_gridspec(3, 6)
ax1 = fig.add_subplot(gs[:2, :])
ax2 = fig.add_subplot(gs[2, :], sharex = ax1)

min_time, max_time = np.min(dataset.times_rv["NEID"]) - 10, np.max(dataset.times_rv["NEID"]) + 10
model_times = np.linspace(min_time+10, max_time+10, 5000)

###################################################### For Model Plotting ######################################################
full_model_inst,components_inst = results.rv.evaluate("NEID", t = model_times, GPregressors = model_times, return_components = True)

phase_model = (((model_times-t0 + 0.5*P) % P)/P) - 0.5
phase_neid = (((times_neid-t0 + 0.5*P) % P)/P) - 0.5
phase_hpf = (((times_hpf-t0 + 0.5*P) % P)/P) - 0.5

plt.setp(ax1.get_xticklabels(), visible=False)
ax1.set_ylabel('RV (m/s)',fontsize=16)

idx = np.argsort(phase_model)

#ax1.plot(phase_model[idx],full_model_inst[idx] - components_inst['mu'], alpha = 0.1, label='Full model',color='black')
ax1.plot(phase_model[idx],results.rv.model["NEID"]['deterministic'][idx] - components_inst['mu'],label = 'Keplerian component', color = 'crimson', lw = 3)
#ax1.plot(phase_model[idx],results.rv.model["NEID"]['GP'][idx], label = 'GP component', alpha = 0.1, color='blue')

# quantile_calc_model,quantile_calc_comp = results.rv.evaluate("NEID", t = model_times, GPregressors = model_times, return_samples = True)
# ax1.plot(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp),0.5,axis=0)[idx],lw=2,color="crimson",zorder=20)
# ax1.fill_between(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp),0.16,axis=0)[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.84,axis=0),alpha=0.3,color="#EE2C2C",lw=0,zorder=-1)
# ax1.fill_between(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp),0.02,axis=0)[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.98,axis=0),alpha=0.2,color="#EE2C2C",lw=0,zorder=-1)
# ax1.fill_between(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp),0.0015,axis=0)[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.9985,axis=0),alpha=0.1,color="#EE2C2C",lw=0,zorder=-1)

####################################################### For Data Plotting #######################################################
full_model,components = results.rv.evaluate("NEID", t = times_neid, GPregressors = times_neid, return_components = True)

ax1.errorbar(phase_neid,rv_neid-components['mu']-results.rv.model["NEID"]["GP"],rv_err_neid,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="yellow",label="NEID")

res_neid = rv_neid-results.rv.model["NEID"]["GP"]-results.rv.model["NEID"]['deterministic']

ax2.errorbar(phase_neid,res_neid,rv_err_neid,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="yellow")

full_model,components = results.rv.evaluate("HPF", t = times_hpf, GPregressors = times_hpf, return_components = True)

ax1.errorbar(phase_hpf,rv_hpf-components['mu']-results.rv.model["HPF"]["GP"],rv_err_hpf,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="blue",label="HPF")

res_hpf = rv_hpf-results.rv.model["HPF"]["GP"]-results.rv.model["HPF"]['deterministic']

ax2.errorbar(phase_hpf,res_hpf,rv_err_hpf,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="blue")

ax2.axhline(0.0,lw=2,color="crimson",zorder=30)

ax2.set_xlim(-0.5,0.5)
ax2.set_ylim(-20,20)
ax2.set_yticks([-10,0,10])
ax2.set_xlabel(r'Phase',fontsize = 20)
ax2.set_ylabel('O - C', fontsize = 20)

ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)

fig.set_facecolor('w')
#plt.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.57, 1.10), ncol=6, fancybox=True, fontsize=15)
#plt.savefig("TOI-2431_RVs_phase.png", bbox_inches="tight", dpi=600)
plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(10,6),dpi=150,constrained_layout=True)

gs = fig.add_gridspec(3, 6)
ax1 = fig.add_subplot(gs[:2, :])
ax2 = fig.add_subplot(gs[2, :], sharex = ax1)

min_time, max_time = np.min(dataset.times_rv["HPF"]) - 10, np.max(dataset.times_rv["HPF"]) + 10
model_times = np.linspace(min_time+10, max_time+10, 5000)

###################################################### For Model Plotting ######################################################
full_model_inst,components_inst = results.rv.evaluate("HPF", t = model_times, GPregressors = model_times, return_components = True)

phase_model = (((model_times-t0 + 0.5*P) % P)/P) - 0.5
phase_hpf = (((times_hpf-t0 + 0.5*P) % P)/P) - 0.5

plt.setp(ax1.get_xticklabels(), visible=False)
ax1.set_ylabel('RV (m/s)',fontsize=14)

idx = np.argsort(phase_model)

#ax1.plot(phase_model[idx],full_model_inst[idx] - components_inst['mu'], alpha = 0.1, label='Full model',color='black')
ax1.plot(phase_model[idx],results.rv.model["HPF"]['deterministic'][idx] - components_inst['mu'],label = 'Keplerian component', color = 'crimson', lw = 3)
#ax1.plot(phase_model[idx],results.rv.model["HPF"]['GP'][idx], label = 'GP component', alpha = 0.1, color='blue')

#quantile_calc_model,quantile_calc_comp = results.rv.evaluate("NEID", t = model_times, GPregressors = model_times, return_samples = True)
#ax1.plot(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp['mu']),0.5,axis=0)[idx],lw=2,color="crimson",zorder=20)
# ax1.fill_between(phase_model[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.16,axis=0),np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.84,axis=0),alpha=0.3,color="#EE2C2C",lw=0,zorder=-1)
# ax1.fill_between(phase_model[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.02,axis=0),np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.98,axis=0),alpha=0.2,color="#EE2C2C",lw=0,zorder=-1)
# ax1.fill_between(phase_model[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.0015,axis=0),np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.9985,axis=0),alpha=0.1,color="#EE2C2C",lw=0,zorder=-1)

####################################################### For Data Plotting #######################################################
full_model,components = results.rv.evaluate("HPF", t = times_hpf, GPregressors = times_hpf, return_components = True)

ax1.errorbar(phase_hpf,rv_hpf-components['mu']-results.rv.model["HPF"]["GP"],rv_err_hpf,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="yellow",label="HPF")

res_hpf = rv_hpf-results.rv.model["HPF"]["GP"]-results.rv.model["HPF"]['deterministic']

ax2.errorbar(phase_hpf,res_hpf,rv_err_hpf,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="yellow")
ax2.axhline(0.0,lw=2,color="crimson",zorder=30)

ax2.set_xlim(-0.5,0.5)
ax2.set_ylim(-20,20)
ax2.set_yticks([-10,0,10])
ax2.set_xlabel(r'Phase',fontsize=14)
ax2.set_ylabel('O - C', fontsize = 14)

ax1.tick_params(labelsize=12)
ax2.tick_params(labelsize=12)

fig.set_facecolor('w')
#plt.tight_layout()
fig.legend(loc='upper center', bbox_to_anchor=(0.57, 1.07),ncol=6, fancybox=True, fontsize=9)
#plt.savefig("TOI-2431_RVs_phase.png", bbox_inches="tight", dpi=600)
plt.show()
plt.close()

# %%
def get_vals(vec):
    fvec   = np.sort(vec)

    fval  = np.median(fvec)
    nn = int(np.around(len(fvec)*0.15865))

    vali,valf = fval - fvec[nn],fvec[-nn] - fval
    return fval,vali,valf
    
def print_mass_radius_rho_sma_planet(rstar=1.0, rstar_err=0.1, mstar=1.0, mstar_err=0.1, r_units=u.Rjup, sma_units=u.AU, m_units=u.Mjup):
    """
    Calculate and print the planet's mass, radius, density, and semi-major axis. If r_star and/or m_star are not sampled they must be added as inputs

    Parameters:
    rstar (float) optional: Mean stellar radius in solar radii. Only if r_star not sampled
    rstar_err (float) optional: Error in stellar radius. Only if r_star not sampled
    mstar (float) optional: Mean stellar mass in solar masses. Only if m_star not sampled
    mstar_err (float) optional: Error in stellar mass. Only if m_star not sampled
    r_units (Astropy Unit): Desired output units for the planet's radius.
    sma_units (Astropy Unit): Desired output units for the semi-major axis.
    m_units (Astropy Unit): Desired output units for the planet's mass.
    """
    # chain = self.fit.chain
    Rs = np.random.normal(rstar, rstar_err, len(results.posteriors['posterior_samples']['K_p1'])) * u.Rsun
    Ms = np.random.normal(mstar, mstar_err, len(results.posteriors['posterior_samples']['K_p1'])) * u.Msun

    rp = results.posteriors['posterior_samples']['p_p1'] * Rs
    rp = rp.to(r_units)
    r_planet_val, r_planet_down, r_planet_up = get_vals(rp.value)
    print(f"R_planet: {r_planet_val:.4f} +{r_planet_up:.4f} -{r_planet_down:.4f} {r_units}")

    P_sec = results.posteriors['posterior_samples']['P_p1'] * u.day
    P_sec = P_sec.to(u.s)
    aRs = (((P_sec**2 * c.G * Ms) / (4 * np.pi**2))**(1/3))
    sma = aRs.to(sma_units)
    sma_val, sma_down, sma_up = get_vals(sma.value)
    print(f"Sma_planet: {sma_val:.4f} +{sma_up:.4f} -{sma_down:.4f} {sma_units}")

    K = results.posteriors['posterior_samples']['K_p1'] * u.m / u.s
    e = 0
    cos_inc = (results.posteriors['posterior_samples']['b_p1'] * Rs) / sma
    cos_inc = np.clip(cos_inc, -1, 1)
    inc = np.arccos(cos_inc)
    inc_val, inc_down, inc_up = get_vals(inc.value)
    print(f"Inclination: {np.degrees(inc_val):.4f} +{np.degrees(inc_up):.4f} -{np.degrees(inc_down):.4f} deg")
    #inc = 73.83677068878853 * np.pi / 180.0  # Convert to radians
    mp = K * np.sqrt(Ms * sma * (1 - e**2) / c.G) / np.sin(inc)
    mp = mp.to(m_units)
    m_planet_val, m_planet_down, m_planet_up = get_vals(mp.value)
    print(f"M_planet: {m_planet_val:.4f} +{m_planet_up:.4f} -{m_planet_down:.4f} {m_units}")

    dens = (3 * mp / (4 * np.pi * rp**3)).to(u.g / u.cm**3)
    dens_val, dens_down, dens_up = get_vals(dens.value)
    print(f"Rho_planet: {dens_val:.4f} +{dens_up:.4f} -{dens_down:.4f} g/cm^3")

# %%
print_mass_radius_rho_sma_planet(rstar=0.66,rstar_err=0.01,mstar=0.66,mstar_err=0.02,r_units=u.Rearth,m_units=u.Mearth)
# Out:
# R_planet: 1.5334 +0.0343 -0.0332 earthRad
# Sma_planet: 0.0063 +0.0001 -0.0001 AU
# Inclination: 73.8179 +1.0121 -1.0121 deg
# M_planet: 5.1839 +1.5961 -1.4972 earthMass
# Rho_planet: 7.8878 +2.4858 -2.3112 g/cm^3

# %%
#We first create a figure with the panel plot layout. (Two at first row and one at second row)
fig = plt.figure(figsize = (18, 14), dpi = 150, constrained_layout = True)

#We then create a 2x2 grid of subplots.
gs = fig.add_gridspec(2, 2, hspace = 0.3)

#Upper Row: Plot 1 and Plot 2, the GP plots for both NEID and HPF data
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

#Lower Row: Plot 3, the RV data and the best fit model using GP
ax3 = fig.add_subplot(gs[1, :])

#--------------------------------------------- PLOT 1: GP Plot NEID ------------------------------------------------

inst = "NEID"
min_time, max_time = np.min(dataset.times_rv[inst]) - 10, np.max(dataset.times_rv[inst]) + 10
model_times = np.linspace(min_time+10, max_time+10, 5000)

###################################################### For Model Plotting ######################################################
full_model_inst,components_inst = results.rv.evaluate(inst, t = model_times, GPregressors = model_times, return_components = True)

jitter = 0

ax1.plot(model_times-2454705,full_model_inst - components_inst['mu'],label='Full model',alpha = 0.2,color='black')
ax1.plot(model_times-2454705,results.rv.model[inst]['deterministic'],label = 'Keplerian component', color = 'crimson')
ax1.plot(model_times-2454705,results.rv.model[inst]['GP'], label = 'GP component', alpha = 0.4, color='blue')

####################################################### For Data Plotting #######################################################
full_model,components = results.rv.evaluate(inst, t = dataset.times_rv[inst], GPregressors = dataset.times_rv[inst], return_components = True)
ax1.errorbar(dataset.times_rv[inst]-2454705, dataset.data_rv[inst] - components['mu'] - results.rv.model[inst]["GP"], \
             yerr = dataset.errors_rv[inst], fmt = 'o', label = inst+' data',mec='cornflowerblue', ecolor='cornflowerblue', mfc='white', \
             elinewidth=1)

ax1.set_xlabel("Time (BJD - 2457000)", fontsize = 22)
ax1.set_ylabel("RV (m/s)", fontsize = 22)
ax1.set_ylim(-20,25)
ax1.tick_params(axis = "both", labelsize = 22)
ax1.legend(fontsize = 17)
ax1.text(5957, 20, "a)", fontsize = 22, ha = "center", va = "center", weight = "bold")

#--------------------------------------------- PLOT 2: GP Plot HPF -------------------------------------------------

inst = "HPF"
min_time, max_time = np.min(dataset.times_rv[inst]) - 10, np.max(dataset.times_rv[inst]) + 10
model_times = np.linspace(min_time+10, max_time+10, 5000)

###################################################### For Model Plotting ######################################################
full_model_inst,components_inst = results.rv.evaluate(inst, t = model_times, GPregressors = model_times, return_components = True)

jitter = 0

ax2.plot(model_times-2454705,full_model_inst - components_inst['mu'],label='Full model',alpha = 0.2,color='black')
ax2.plot(model_times-2454705,results.rv.model[inst]['deterministic'],label = 'Keplerian component', color = 'crimson')
ax2.plot(model_times-2454705,results.rv.model[inst]['GP'], label = 'GP component', alpha = 0.4, color='blue')

####################################################### For Data Plotting #######################################################
full_model,components = results.rv.evaluate(inst, t = dataset.times_rv[inst], GPregressors = dataset.times_rv[inst], return_components = True)
ax2.errorbar(dataset.times_rv[inst]-2454705, dataset.data_rv[inst] - components['mu'] - results.rv.model[inst]["GP"], \
             yerr = dataset.errors_rv[inst], fmt = 'o', label = inst+' data',mec='cornflowerblue', ecolor='cornflowerblue', mfc='white', \
             elinewidth=1)

ax2.set_xlabel("Time (BJD - 2457000)", fontsize = 22)
ax2.set_ylabel("RV (m/s)", fontsize = 22)
ax2.tick_params(axis = "both", labelsize = 22)
ax2.legend(fontsize = 17)
ax2.text(5969, 11.9, "b)", fontsize = 22, ha = "center", va = "center", weight = "bold")

#--------------------------------------------- PLOT 3: RV Fit with GP ----------------------------------------------

min_time, max_time = np.min(dataset.times_rv["NEID"]) - 10, np.max(dataset.times_rv["NEID"]) + 10
model_times = np.linspace(min_time+10, max_time+10, 5000)

###################################################### For Model Plotting ######################################################
full_model_inst,components_inst = results.rv.evaluate("NEID", t = model_times, GPregressors = model_times, return_components = True)

phase_model = (((model_times-t0 + 0.5*P) % P)/P) - 0.5
phase_neid = (((times_neid-t0 + 0.5*P) % P)/P) - 0.5
phase_hpf = (((times_hpf-t0 + 0.5*P) % P)/P) - 0.5

ax3.set_ylabel('RV (m/s)', fontsize = 22)

idx = np.argsort(phase_model)

#ax1.plot(phase_model[idx],full_model_inst[idx] - components_inst['mu'], alpha = 0.1, label='Full model',color='black')
ax3.plot(phase_model[idx],results.rv.model["NEID"]['deterministic'][idx] - components_inst['mu'],label = 'Keplerian component', color = 'crimson', lw = 3)
#ax1.plot(phase_model[idx],results.rv.model["NEID"]['GP'][idx], label = 'GP component', alpha = 0.1, color='blue')

# quantile_calc_model,quantile_calc_comp = results.rv.evaluate("NEID", t = model_times, GPregressors = model_times, return_samples = True)
# ax1.plot(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp),0.5,axis=0)[idx],lw=2,color="crimson",zorder=20)
# ax1.fill_between(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp),0.16,axis=0)[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.84,axis=0),alpha=0.3,color="#EE2C2C",lw=0,zorder=-1)
# ax1.fill_between(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp),0.02,axis=0)[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.98,axis=0),alpha=0.2,color="#EE2C2C",lw=0,zorder=-1)
# ax1.fill_between(phase_model[idx],np.quantile(quantile_calc_model-np.median(quantile_calc_comp),0.0015,axis=0)[idx],np.quantile(results.rv.model["NEID"]['deterministic'][idx],0.9985,axis=0),alpha=0.1,color="#EE2C2C",lw=0,zorder=-1)

####################################################### For Data Plotting #######################################################
full_model,components = results.rv.evaluate("NEID", t = times_neid, GPregressors = times_neid, return_components = True)

ax3.errorbar(phase_neid,rv_neid-components['mu']-results.rv.model["NEID"]["GP"],rv_err_neid,fmt="o",markersize=10,color="k",capsize=2,elinewidth=1,markerfacecolor="yellow",label="NEID")

res_neid = rv_neid-results.rv.model["NEID"]["GP"]-results.rv.model["NEID"]['deterministic']

full_model,components = results.rv.evaluate("HPF", t = times_hpf, GPregressors = times_hpf, return_components = True)

ax3.errorbar(phase_hpf,rv_hpf-components['mu']-results.rv.model["HPF"]["GP"],rv_err_hpf,fmt="o",markersize=10,color="k",capsize=2,elinewidth=1,markerfacecolor="blue",label="HPF")

res_hpf = rv_hpf-results.rv.model["HPF"]["GP"]-results.rv.model["HPF"]['deterministic']

ax3.tick_params(labelsize = 22)
ax3.set_xlim(-0.5,0.5)
ax3.set_xlabel(r'Phase',fontsize = 22)
ax3.legend(fontsize = 19)

ax3.text(-0.48, 11, "c)", fontsize = 22, ha = "center", va = "center", weight = "bold")

plt.tight_layout()
plt.savefig("toi_2431_GP_fit.png", dpi = 500)
plt.show()

# %% [markdown]
# ### Old Code

# %%
# from matplotlib.lines import Line2D

# fig, axes = plt.subplots(2, 2, figsize=(12, 6), dpi=150, gridspec_kw={'height_ratios': [2, 1]}, sharex='col')

# ax1, ax2 = axes[:, 0]  #Left column (Transit plot)
# ax3, ax4 = axes[:, 1]  #Right column (RV plot)

# #--------- LEFT PANEL: TRANSIT LIGHT CURVE ---------
# phase_bin, flux_bin = bin_lc(phase_tess, flux_tess)

# ax1.errorbar(phase_tess * P * 24., flux_tess - gp_model_tess, flux_err_tess, fmt='.', alpha=0.1, color="cornflowerblue", label = "TESS Data")
# idx = np.argsort(phase_tess)
# ax1.plot(phase_tess[idx] * P * 24., model_tess[idx], color='crimson', zorder=10, lw=2)
# ax1.plot((phase_bin) * P * 24., flux_bin, "o", color="k", zorder=5, label = "Binned TESS data")
# ax1.set_ylim(0.996, 1.005)
# ax1.set_ylabel('Relative flux', fontsize=14)
# plt.setp(ax1.get_xticklabels(), visible=False)

# res = flux_tess - gp_model_tess - model_tess
# phase_res_bin, res_bin = bin_lc(phase_tess, res)

# ax2.errorbar(phase_tess * P * 24., res, flux_err_tess, fmt='.', alpha=0.1, color="cornflowerblue")
# ax2.axhline(0.0, lw=2, color="crimson", zorder=30)
# ax2.plot((phase_bin) * P * 24., res_bin, "o", color="k", zorder=5)
# ax2.set_xlim(-2.5, 2.5)
# ax2.set_ylim(-0.004, 0.004)
# ax2.set_xlabel(r'Hours from mid-transit', fontsize=14)
# ax2.set_ylabel('O - C', fontsize=14)

# #ax1.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3, fancybox=True, fontsize=9)
# ax1.legend(
#     handles=[
#         Line2D([0], [0], marker='o', color='cornflowerblue', markersize=2, linestyle='None', label="TESS Data", alpha=1.0),
#         Line2D([0], [0], marker='o', color='k', markersize=6, linestyle='None', label="Binned TESS data")
#     ],
#     loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3, fancybox=True, fontsize=9
# )

# # Label "a)"
# ax1.text(-2.4, 1.004, "a)", fontsize=16, fontweight='bold')

# #--------- RIGHT PANEL: RADIAL VELOCITY CURVE ---------
# phase_model = (((model_times - t0 + 0.5 * P) % P) / P) - 0.5
# phase_neid = (((times_neid - t0 + 0.5 * P) % P) / P) - 0.5
# phase_hpf = (((times_hpf - t0 + 0.5 * P) % P) / P) - 0.5

# ax3.errorbar(phase_neid, rv_neid - gamma_neid, rv_err_neid, fmt="o", color="k", capsize=2, elinewidth=1, markerfacecolor="yellow", label="NEID")
# ax3.errorbar(phase_hpf, rv_hpf - gamma_hpf, rv_err_hpf, fmt="o", color="k", capsize=2, elinewidth=1, markerfacecolor="yellow", label="HPF")

# idx = np.argsort(phase_model)
# ax3.plot(phase_model[idx], np.quantile(keplerian, 0.5, axis=0)[idx], lw=2, color="crimson", zorder=20)
# ax3.fill_between(phase_model[idx], np.quantile(keplerian, 0.16, axis=0)[idx], np.quantile(keplerian, 0.84, axis=0)[idx], alpha=0.3, color="#EE2C2C", lw=0, zorder=-1)
# ax3.fill_between(phase_model[idx], np.quantile(keplerian, 0.02, axis=0)[idx], np.quantile(keplerian, 0.98, axis=0)[idx], alpha=0.2, color="#EE2C2C", lw=0, zorder=-1)
# ax3.fill_between(phase_model[idx], np.quantile(keplerian, 0.0015, axis=0)[idx], np.quantile(keplerian, 0.9985, axis=0)[idx], alpha=0.1, color="#EE2C2C", lw=0, zorder=-1)

# ax3.set_ylabel('RV (m/s)', fontsize=14)
# plt.setp(ax3.get_xticklabels(), visible=False)

# res_neid = rv_neid - gamma_neid - model_neid
# res_hpf = rv_hpf - gamma_hpf - model_hpf

# ax4.errorbar(phase_neid, res_neid, rv_err_neid, fmt="o", color="k", capsize=2, elinewidth=1, markerfacecolor="yellow")
# ax4.errorbar(phase_hpf, res_hpf, rv_err_hpf, fmt="o", color="k", capsize=2, elinewidth=1, markerfacecolor="red")
# ax4.axhline(0.0, lw=2, color="crimson", zorder=30)

# ax4.set_xlim(-0.5, 0.5)
# ax4.set_ylim(-10, 10)
# ax4.set_yticks([-5, 0, 5])
# ax4.set_xlabel(r'Phase', fontsize=14)
# ax4.set_ylabel('O - C', fontsize=14)

# ax3.text(-0.48, 12, "b)", fontsize=16, fontweight='bold')

# fig.set_facecolor('w')
# ax3.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3, fancybox=True, fontsize=9)

# #plt.savefig("TOI-2431_Transit_RV.png", bbox_inches="tight", dpi=600)
# plt.show()
# plt.close()

# %%
# def plot_rv(inst):

#     global results
#     global dataset
    
#     fig = plt.figure(figsize=(4,4),dpi=150,constrained_layout=True)
    
#     min_time, max_time = np.min(dataset.times_rv[inst])-10,\
#                          np.max(dataset.times_rv[inst])+10
    
#     model_times = np.linspace(min_time,max_time,100000)
    
#     keplerian = results.rv.evaluate(inst, t = model_times, GPregressors = model_times) - np.median(results.posteriors['posterior_samples']['mu_'+inst])
    
#     color = 'cornflowerblue'
    
#     # Evaluate the median jitter for the instrument:
#     jitter = 0
#     # Evaluate the median systemic-velocity:
#     mu = np.median(results.posteriors['posterior_samples']['mu_'+inst])

#     # Plot original errorbars + jitter (added in quadrature):
#     plt.errorbar(dataset.times_rv[inst]-2457000,dataset.data_rv[inst]-mu,\
#                  yerr = np.sqrt(dataset.errors_rv[inst]**2+jitter**2),fmt='o',\
#                  mec=color, ecolor=color, mfc = 'white', label=inst,\
#                  alpha = 0.5, zorder=5)
    
#     # Plot Keplerian model:
#     plt.plot(model_times-2457000, keplerian,color='black',zorder=1)
#     plt.ylabel('RV (m/s)', fontsize = 11)
#     plt.xlabel('Time (BJD - 2457000)', fontsize = 11)
#     plt.show()

#     keplerian = results.rv.evaluate(inst, t = dataset.times_rv[inst], GPregressors = dataset.times_rv[inst]) - np.median(results.posteriors['posterior_samples']['mu_'+inst])

#     GP = results.rv.model[inst]["GP"]
    
#     return dataset.times_rv[inst], dataset.data_rv[inst], np.sqrt(dataset.errors_rv[inst]**2+jitter**2), mu, keplerian, GP

# %%
# times_neid, rv_neid, rv_err_neid, gamma_neid, model_neid, GP_neid =  plot_rv("NEID")
# times_hpf, rv_hpf, rv_err_hpf, gamma_hpf, model_hpf, GP_hpf = plot_rv("HPF")

# %%
# min_time, max_time = np.min(dataset.times_rv["NEID"]),np.max(dataset.times_rv["NEID"])
# model_times = np.linspace(min_time-10,max_time+10,5000)    
# keplerian = results.rv.evaluate("NEID", t = model_times, GPregressors = model_times, nsamples = 5000, return_samples = True)[0] - np.median(results.posteriors['posterior_samples']['mu_NEID'])

# %%
# fig = plt.figure(figsize=(10,6),dpi=150,constrained_layout=True)

# gs = fig.add_gridspec(3, 6)
# ax1 = fig.add_subplot(gs[:2, :])
# ax2 = fig.add_subplot(gs[2, :], sharex = ax1)

# phase_model = (((model_times-t0 + 0.5*P) % P)/P) - 0.5
# phase_neid = (((times_neid-t0 + 0.5*P) % P)/P) - 0.5
# phase_hpf = (((times_hpf-t0 + 0.5*P) % P)/P) - 0.5

# plt.setp(ax1.get_xticklabels(), visible=False)
# ax1.set_ylabel('RV (m/s)',fontsize=14)

# ax1.errorbar(phase_neid,rv_neid-gamma_neid-GP_neid,rv_err_neid,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="yellow",label="NEID")
# ax1.errorbar(phase_hpf,rv_hpf-gamma_hpf-GP_hpf,rv_err_hpf,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="red",label="HPF")
# idx = np.argsort(phase_model)
# ax1.plot(phase_model[idx],np.quantile(keplerian,0.5,axis=0)[idx],lw=2,color="crimson",zorder=20)
# ax1.fill_between(phase_model[idx],np.quantile(keplerian,0.16,axis=0)[idx],np.quantile(keplerian,0.84,axis=0)[idx],alpha=0.3,color="#EE2C2C",lw=0,zorder=-1)
# ax1.fill_between(phase_model[idx],np.quantile(keplerian,0.02,axis=0)[idx],np.quantile(keplerian,0.98,axis=0)[idx],alpha=0.2,color="#EE2C2C",lw=0,zorder=-1)
# ax1.fill_between(phase_model[idx],np.quantile(keplerian,0.0015,axis=0)[idx],np.quantile(keplerian,0.9985,axis=0)[idx],alpha=0.1,color="#EE2C2C",lw=0,zorder=-1)

# res_neid = rv_neid-gamma_neid-model_neid
# res_hpf = rv_hpf-gamma_hpf-model_hpf

# ax2.errorbar(phase_neid,res_neid,rv_err_neid,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="yellow")
# ax2.errorbar(phase_hpf,res_hpf,rv_err_hpf,fmt="o",color="k",capsize=2,elinewidth=1,markerfacecolor="red")
# ax2.axhline(0.0,lw=2,color="crimson",zorder=30)

# ax2.set_xlim(-0.5,0.5)
# ax2.set_ylim(-40,40)
# ax2.set_yticks([-25,0,25])
# ax2.set_xlabel(r'Phase',fontsize=14)
# ax2.set_ylabel('O - C', fontsize = 14)

# ax1.tick_params(labelsize=12)
# ax2.tick_params(labelsize=12)

# fig.set_facecolor('w')
# #plt.tight_layout()
# fig.legend(loc='upper center', bbox_to_anchor=(0.57, 1.07),ncol=6, fancybox=True, fontsize=9)
# #plt.savefig("TOI-2431_RVs_phase.png", bbox_inches="tight", dpi=600)
# plt.show()
# plt.close()
